# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #introduction to regression with netural networ with tensorflow
#
# regression: predict a numerical variable based on some other combination of variables,
# * predict a number

# %%
# Create data for view and fit

#create features
X = np.array([-7.0, -4.0, -1.0, 2.0, 5.0, 8.0, 11.0, 14.0])

# Create labels
y = np.array([3.0, 6.0, 9.0, 12.0, 15.0, 18.0, 21.0, 24.0])

# Visualize it
plt.scatter(X, y)

# %%
# Input and output shapes

# %%
# create a demo tensor for our housing price prediction problem
house_info = tf.constant(['bedroom', 'bathroom', 'garage'])
house_price = tf.constant([939700])
house_info, house_price
# Out:
# (<tf.Tensor: shape=(3,), dtype=string, numpy=array([b'bedroom', b'bathroom', b'garage'], dtype=object)>,
#  <tf.Tensor: shape=(1,), dtype=int32, numpy=array([939700], dtype=int32)>)

# %%
input_shape = X.shape
output_shape = y.shape
input_shape, output_shape
# Out:
# ((8,), (8,))

# %%
X[0], y[0]
# Out:
# (-7.0, 3.0)

# %%
# turn our NumPy arrays into tensors with dtype float32
X = tf.constant(X)
y = tf.constant(y)
X, y
# Out:
# (<tf.Tensor: shape=(8,), dtype=float64, numpy=array([-7., -4., -1.,  2.,  5.,  8., 11., 14.])>,
#  <tf.Tensor: shape=(8,), dtype=float64, numpy=array([ 3.,  6.,  9., 12., 15., 18., 21., 24.])>)

# %%
input_shape = X[0].shape
ouptut_shape = y[0].shape
input_shape, output_shape
# Out:
# (TensorShape([]), (8,))

# %%
plt.scatter(X,y)

# %%
# Steps in modelling with TensorFlow

# 1. Creating a model - define the input and output layers, as well as the hidden layers of a deep learning model
# 2. Compiling a model - define the loss function (in other words, the function which tells our model how wrong it is) and the optimizer (tells our model how to improve the patterns its learning) and evaluation metrics (what we can use to interpret the performance of our model).
# 3. Fitting a model - letting the model try to find patterns between X & y (features and labels)

# %%
# set random seed
tf.random.set_seed(42)
# 1. Create a model using the Sequential API
model = tf.keras.Sequential([
    tf.keras.layers.Dense(1)
])

# 2. Compile the model
model.compile(loss=tf.keras.losses.mae,
              optimizer= tf.keras.optimizers.SGD(),
              metrics=['mae'])
# 3. Fit the model
model.fit(tf.expand_dims(X, axis=-1), y, epochs=5)
# Out:
# Epoch 1/5
# 1/1 [==============================] - 0s 116ms/step - loss: 11.6658 - mae: 11.6658
# Epoch 2/5
# 1/1 [==============================] - 0s 2ms/step - loss: 11.5333 - mae: 11.5333
# Epoch 3/5
# 1/1 [==============================] - 0s 1ms/step - loss: 11.4008 - mae: 11.4008
# Epoch 4/5
# 1/1 [==============================] - 0s 1ms/step - loss: 11.2683 - mae: 11.2683
# Epoch 5/5
# 1/1 [==============================] - 0s 2ms/step - loss: 11.1358 - mae: 11.1358

# %%
y_pred = model.predict([17.0])
y_pred
# Out:
# 1/1 [==============================] - 0s 25ms/step
# array([[11.933879]], dtype=float32)

# %%
X,y
# Out:
# (<tf.Tensor: shape=(8,), dtype=float64, numpy=array([-7., -4., -1.,  2.,  5.,  8., 11., 14.])>,
#  <tf.Tensor: shape=(8,), dtype=float64, numpy=array([ 3.,  6.,  9., 12., 15., 18., 21., 24.])>)

# %%
y_pred + 11
# Out:
# array([[22.93388]], dtype=float32)

# %% [markdown]
# # Improving the model
# We can improve our model, by altering the steps we took to create a model.
#
# 1. Create a model - here we might add more layers, increase the number of hidden units ( all called neurons) within each of the hidden layers, change the activation function of each layer
# 2. Compiling a model - here we might change the optimization function or perhaps the learning rate of the optimization  function
# 3. Fitting a model - here we might fit a model for moire epochs (leave it training for longer) or on more data (give the model more examples to learn from).

# %%
# rebuild the model

# 1. Create the model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(1)
])

# 2. Compile the model
model.compile(loss=tf.keras.losses.mae,
              optimizer = tf.keras.optimizers.SGD(),
              metrics=['mae'])
# 3. Fit the model
model.fit(tf.expand_dims(X, axis=-1), y, epochs=100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 239ms/step - loss: 10.3632 - mae: 10.3632
# Epoch 2/100
# 1/1 [==============================] - 0s 4ms/step - loss: 10.2307 - mae: 10.2307
# Epoch 3/100
# 1/1 [==============================] - 0s 3ms/step - loss: 10.0982 - mae: 10.0982
# Epoch 4/100
# 1/1 [==============================] - 0s 3ms/step - loss: 9.9657 - mae: 9.9657
# Epoch 5/100
# 1/1 [==============================] - 0s 2ms/step - loss: 9.8332 - mae: 9.8332
# Epoch 6/100
# 1/1 [==============================] - 0s 1ms/step - loss: 9.7007 - mae: 9.7007
# Epoch 7/100
# 1/1 [==============================] - 0s 1ms/step - loss: 9.5682 - mae: 9.5682
# Epoch 8/100
# 1/1 [==============================] - 0s 1ms/step - loss: 9.4357 - mae: 9.4357
# Epoch 9/100
# 1/1 [==============================] - 0s 1ms/step - loss: 9.3032 - mae: 9.3032
# Epoch 10/100
# 1/1 [==============================] - 0s 1ms/step - loss: 9.1707 - mae: 9.1707
# Epoch 11/100
# ...

# %%
# remind ourselves of the data
X,y
# Out:
# (<tf.Tensor: shape=(8,), dtype=float64, numpy=array([-7., -4., -1.,  2.,  5.,  8., 11., 14.])>,
#  <tf.Tensor: shape=(8,), dtype=float64, numpy=array([ 3.,  6.,  9., 12., 15., 18., 21., 24.])>)

# %%
# Let's see if our model's prediction has improved
model.predict([17.0])
# Out:
# 1/1 [==============================] - 0s 26ms/step
# array([[29.72842]], dtype=float32)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(1)
])

model.compile(loss=tf.keras.losses.mae,
                optimizer = tf.keras.optimizers.Adam(lr=0.01),
                metrics=['mae'])

model.fit(tf.expand_dims(X, axis=-1), y, epochs=100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 113ms/step - loss: 14.4491 - mae: 14.4491
# Epoch 2/100
# 1/1 [==============================] - 0s 1ms/step - loss: 14.4041 - mae: 14.4041
# Epoch 3/100
# 1/1 [==============================] - 0s 1ms/step - loss: 14.3591 - mae: 14.3591
# Epoch 4/100
# 1/1 [==============================] - 0s 1ms/step - loss: 14.3141 - mae: 14.3141
# Epoch 5/100
# 1/1 [==============================] - 0s 1ms/step - loss: 14.2691 - mae: 14.2691
# Epoch 6/100
# 1/1 [==============================] - 0s 907us/step - loss: 14.2241 - mae: 14.2241
# Epoch 7/100
# 1/1 [==============================] - 0s 917us/step - loss: 14.1791 - mae: 14.1791
# Epoch 8/100
# 1/1 [==============================] - 0s 1ms/step - loss: 14.1341 - mae: 14.1341
# Epoch 9/100
# 1/1 [==============================] - 0s 1ms/step - loss: 14.0891 - mae: 14.0891
# Epoch 10/100
# 1/1 [==============================] - 0s 1ms/step - loss: 14.0441 - mae: 14.0441
# ...

# %%
model.predict([17.0])
# Out:
# 1/1 [==============================] - 0s 28ms/step
# array([[13.390018]], dtype=float32)

# %%
#Create a model

model = tf.keras.Sequential([
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(1)
])

#2. Compile the model
model.compile(loss='mae',
              optimizer= tf.keras.optimizers.SGD(),
              metrics=['mae'])
#3. Fit the model
model.fit(tf.expand_dims(X, axis=-1),y, epochs=100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 130ms/step - loss: 12.5578 - mae: 12.5578
# Epoch 2/100
# 1/1 [==============================] - 0s 1ms/step - loss: 11.9974 - mae: 11.9974
# Epoch 3/100
# 1/1 [==============================] - 0s 1ms/step - loss: 11.4265 - mae: 11.4265
# Epoch 4/100
# 1/1 [==============================] - 0s 1ms/step - loss: 10.8386 - mae: 10.8386
# Epoch 5/100
# 1/1 [==============================] - 0s 975us/step - loss: 10.2402 - mae: 10.2402
# Epoch 6/100
# 1/1 [==============================] - 0s 1ms/step - loss: 9.6155 - mae: 9.6155
# Epoch 7/100
# 1/1 [==============================] - 0s 1ms/step - loss: 8.9585 - mae: 8.9585
# Epoch 8/100
# 1/1 [==============================] - 0s 1ms/step - loss: 8.2813 - mae: 8.2813
# Epoch 9/100
# 1/1 [==============================] - 0s 970us/step - loss: 7.5719 - mae: 7.5719
# Epoch 10/100
# 1/1 [==============================] - 0s 951us/step - loss: 6.8114 - mae: 6.8114
# Epoch 11/100
# ...

# %%
# Let's try to make a prediction with our model
y_pred = model.predict([17.0])
y_pred
# Out:
# 1/1 [==============================] - 0s 28ms/step
# array([[32.51134]], dtype=float32)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(1)
])

model.compile(loss='mae',
                optimizer=tf.keras.optimizers.Adam(lr=0.01),
                metrics=['mae'])

model.fit(tf.expand_dims(X, axis=-1), y, epochs=100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 148ms/step - loss: 13.4517 - mae: 13.4517
# Epoch 2/100
# 1/1 [==============================] - 0s 2ms/step - loss: 10.6396 - mae: 10.6396
# Epoch 3/100
# 1/1 [==============================] - 0s 1ms/step - loss: 7.3118 - mae: 7.3118
# Epoch 4/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.1066 - mae: 4.1066
# Epoch 5/100
# 1/1 [==============================] - 0s 1ms/step - loss: 6.0090 - mae: 6.0090
# Epoch 6/100
# 1/1 [==============================] - 0s 1ms/step - loss: 5.7508 - mae: 5.7508
# Epoch 7/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.3111 - mae: 4.3111
# Epoch 8/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.9530 - mae: 3.9530
# Epoch 9/100
# 1/1 [==============================] - 0s 1ms/step - loss: 5.1386 - mae: 5.1386
# Epoch 10/100
# 1/1 [==============================] - 0s 1ms/step - loss: 5.0107 - mae: 5.0107
# Epoch 11/100
# ...

# %%
y_pred = model.predict([17.0])
y_pred
# Out:
# 1/1 [==============================] - 0s 32ms/step
# array([[28.323662]], dtype=float32)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(1)
])

model.compile(loss='mae',
                optimizer=tf.keras.optimizers.Adam(lr=0.0001),
                metrics=['mae'])

model.fit(tf.expand_dims(X, axis=-1), y, epochs=100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 150ms/step - loss: 13.5947 - mae: 13.5947
# Epoch 2/100
# 1/1 [==============================] - 0s 2ms/step - loss: 13.5583 - mae: 13.5583
# Epoch 3/100
# 1/1 [==============================] - 0s 1ms/step - loss: 13.5222 - mae: 13.5222
# Epoch 4/100
# 1/1 [==============================] - 0s 1ms/step - loss: 13.4863 - mae: 13.4863
# Epoch 5/100
# 1/1 [==============================] - 0s 1ms/step - loss: 13.4512 - mae: 13.4512
# Epoch 6/100
# 1/1 [==============================] - 0s 2ms/step - loss: 13.4167 - mae: 13.4167
# Epoch 7/100
# 1/1 [==============================] - 0s 1ms/step - loss: 13.3828 - mae: 13.3828
# Epoch 8/100
# 1/1 [==============================] - 0s 2ms/step - loss: 13.3489 - mae: 13.3489
# Epoch 9/100
# 1/1 [==============================] - 0s 1ms/step - loss: 13.3149 - mae: 13.3149
# Epoch 10/100
# 1/1 [==============================] - 0s 1ms/step - loss: 13.2817 - mae: 13.2817
# Epoch 11/100
# ...

# %%
y_pred = model.predict([17.0])
y_pred
# Out:
# 1/1 [==============================] - 0s 34ms/step
# array([[9.894702]], dtype=float32)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(1)
])

model.compile(loss='mae',
                optimizer=tf.keras.optimizers.Adam(lr=0.01),
                metrics=['mae'])

model.fit(tf.expand_dims(X, axis=-1), y, epochs=100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 142ms/step - loss: 13.4480 - mae: 13.4480
# Epoch 2/100
# 1/1 [==============================] - 0s 2ms/step - loss: 11.4380 - mae: 11.4380
# Epoch 3/100
# 1/1 [==============================] - 0s 1ms/step - loss: 9.6146 - mae: 9.6146
# Epoch 4/100
# 1/1 [==============================] - 0s 1ms/step - loss: 6.6867 - mae: 6.6867
# Epoch 5/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.0614 - mae: 4.0614
# Epoch 6/100
# 1/1 [==============================] - 0s 1ms/step - loss: 5.9255 - mae: 5.9255
# Epoch 7/100
# 1/1 [==============================] - 0s 986us/step - loss: 6.0478 - mae: 6.0478
# Epoch 8/100
# 1/1 [==============================] - 0s 1ms/step - loss: 5.1036 - mae: 5.1036
# Epoch 9/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.8005 - mae: 3.8005
# Epoch 10/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.0862 - mae: 4.0862
# Epoch 11/100
# ...

# %%
y_pred = model.predict([17.0])
y_pred
# Out:
# 1/1 [==============================] - 0s 36ms/step
# array([[25.844042]], dtype=float32)

# %%
X = tf.range(-100, 100, 4)
X
y=X+10
y
# Out:
# <tf.Tensor: shape=(50,), dtype=int32, numpy=
# array([-90, -86, -82, -78, -74, -70, -66, -62, -58, -54, -50, -46, -42,
#        -38, -34, -30, -26, -22, -18, -14, -10,  -6,  -2,   2,   6,  10,
#         14,  18,  22,  26,  30,  34,  38,  42,  46,  50,  54,  58,  62,
#         66,  70,  74,  78,  82,  86,  90,  94,  98, 102, 106], dtype=int32)>

# %%
import matplotlib.pyplot as plt
# plt.scatter(tf.expand_dims(X, axis=-1), y)
plt.scatter(X, y)

# %% [markdown]
# ###
# * Training Set: the model learns from this data, which is typically 70-80% of the total data you have available
# * Validation Set: the model learns from this data, which is typically 10-15% of the total data you have available
# * Testing Set: the model gets evaluated on this dat to test what it has learned, this set is typically 70-80% of the total data you have available.

# %%
len(X)
# Out:
# 50

# %%
X_train = X[:40]
y_train = y[:40]
X_test = X[40:]
y_test = y[40:]

len(X_train), len(X_test), len(y_train), len(y_test)
# Out:
# (40, 10, 40, 10)

# %%
#Visualization

plt.figure(figsize=(10,7))
# Plot training data in blue
plt.scatter(X_train, y_train, c="b", label="Training data")
# Plot test data in green
plt.scatter(X_test, y_test, c='g', label = 'Testing Data')
plt.legend()

# %%
# 1. Create a model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(1)
])

# 2. Compile the model
model.compile(loss=tf.keras.losses.mae,
                optimizer=tf.keras.optimizers.SGD(),
                metrics=['mae'])

# 3. Fit the model
model.fit(tf.expand_dims(X_train, axis=-1), y_train, epochs=100)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 0s 1ms/step - loss: 30.2952 - mae: 30.2952
# Epoch 2/100
# 2/2 [==============================] - 0s 1ms/step - loss: 9.6750 - mae: 9.6750
# Epoch 3/100
# 2/2 [==============================] - 0s 1ms/step - loss: 10.9190 - mae: 10.9190
# Epoch 4/100
# 2/2 [==============================] - 0s 852us/step - loss: 9.4026 - mae: 9.4026
# Epoch 5/100
# 2/2 [==============================] - 0s 2ms/step - loss: 10.2884 - mae: 10.2884
# Epoch 6/100
# 2/2 [==============================] - 0s 989us/step - loss: 9.5354 - mae: 9.5354
# Epoch 7/100
# 2/2 [==============================] - 0s 1ms/step - loss: 8.6573 - mae: 8.6573
# Epoch 8/100
# 2/2 [==============================] - 0s 1ms/step - loss: 9.0449 - mae: 9.0449
# Epoch 9/100
# 2/2 [==============================] - 0s 1ms/step - loss: 18.9822 - mae: 18.9822
# Epoch 10/100
# 2/2 [==============================] - 0s 1ms/step - loss: 10.2376 - mae: 10.2376
# Epoch 11/100
# ...

# %%
tf.random.set_seed(42)

# 1. Create a model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(1, input_shape=[1])
])

    
# 2. Compile the model

model.compile(loss=tf.keras.losses.mae,
                optimizer=tf.keras.optimizers.SGD(),
                metrics=['mae'])

# %%
model.summary()
# Out:
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_39 (Dense)            (None, 1)                 2
#
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Total params: total number of parameters in the model
# Trainable params: these are the parameters that the model can update as it trains
# Non-trainable params: these parameters arent updated during training (this is typical when you bring in already learn patterns or parameters from other models during transfer learning)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(5, input_shape=[1])
])

    
# 2. Compile the model

model.compile(loss=tf.keras.losses.mae,
                optimizer=tf.keras.optimizers.SGD(),
                metrics=['mae'])
model.summary()
# Out:
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_40 (Dense)            (None, 5)                 10
#
# ...
# Total params: 10
# Trainable params: 10
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(10, input_shape=[1], name='input_layer' ),
    tf.keras.layers.Dense(1, name = 'output_layer' ) 
])

    
# 2. Compile the model

model.compile(loss=tf.keras.losses.mae,
                optimizer=tf.keras.optimizers.Adam(lr=0.01),
                metrics=['mae'])
model.summary()
# Out:
# Model: "sequential_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_layer (Dense)         (None, 10)                20
#
#  output_layer (Dense)        (None, 1)                 11
#
# ...
# Total params: 31
# Trainable params: 31
# Non-trainable params: 0
# _________________________________________________________________
# /Users/kinhanglo/Desktop/machine-learning/Machine-Learning-environment/env/lib/python3.10/site-packages/keras/optimizers/optimizer_v2/adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
model.fit(tf.expand_dims(X_train, axis=-1), y_train, epochs=100, verbose=0)

# %%
model.summary()
# Out:
# Model: "sequential_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_layer (Dense)         (None, 10)                20
#
#  output_layer (Dense)        (None, 1)                 11
#
# ...
# Total params: 31
# Trainable params: 31
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model = model, show_shapes=True)

# %%
plot_model(model = model, show_shapes=True)

# %% [markdown]
# ## Visualing our model's predictions
#
# To visualize predictions, it's a good idea to plot themn against the ground truth labels
# Often you will see this in the form of y_test or y_true versus y_pred (ground truth versus your model's predictions)

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# 1/1 [==============================] - 0s 22ms/step
# array([[ 68.462395],
#        [ 72.382774],
#        [ 76.30314 ],
#        [ 80.22351 ],
#        [ 84.14388 ],
#        [ 88.06425 ],
#        [ 91.98461 ],
#        [ 95.905   ],
#        [ 99.82537 ],
#        [103.74573 ]], dtype=float32)

# %%
def plot_predictions(train_data=X_train,
                     train_labels=y_train,
                     test_data=X_test,
                     test_labels=y_test,
                     predictions=y_pred):
    """
    Plots training data, test data and compares predictions to ground truth labels
    """
    plt.figure(figsize= (10,7))
    # Plot training data in blue
    plt.scatter(train_data, train_labels, c="b", label="Training data")
    # Plot test data in green
    plt.scatter(test_data, test_labels, c='g', label = 'Testing Data')
    # Plot model's predictions in red
    plt.scatter(test_data, predictions, c='r', label = 'Predictions')
    # Show the legend
    plt.legend();

# %%
plot_predictions()

# %%
plot_predictions(train_data=X_train,
                     train_labels=y_train,
                     test_data=X_test,
                        test_labels=y_test,
                        predictions=y_pred)

# %% [markdown]
# ## Evaluating our model's predictions with regression evaluation metrics
#
# Depending on the problem you re working on, there will be different evaluation metrics to evaluate your model's performnace.
#
# Since we're working on a regression, two of the main
# * MAE - mean absolute error, "on average, how wrong is each of my model's predictions"
# * MSE - mean squared error, "square the average squared error"

# %%
# Evaluate the model on the test

model.evaluate(X_test, y_test)
# Out:
# 1/1 [==============================] - 0s 104ms/step - loss: 1.8959 - mae: 1.8959
# [1.8959343433380127, 1.8959343433380127]

# %%
# calculate the mean absolute error

# %%
y_pred = tf.constant(y_pred)
y_pred = tf.squeeze(y_pred)
y_pred
# Out:
# <tf.Tensor: shape=(10,), dtype=float32, numpy=
# array([ 68.462395,  72.382774,  76.30314 ,  80.22351 ,  84.14388 ,
#         88.06425 ,  91.98461 ,  95.905   ,  99.82537 , 103.74573 ],
#       dtype=float32)>

# %%
y_test = tf.squeeze(y_test)
y_test = tf.cast(y_test, dtype=tf.float32)
y_test
# Out:
# <tf.Tensor: shape=(10,), dtype=float32, numpy=
# array([ 70.,  74.,  78.,  82.,  86.,  90.,  94.,  98., 102., 106.],
#       dtype=float32)>

# %% [markdown]
# To calculate the mean absolute error (MAE) between two arrays, you need to find the absolute difference between each pair of corresponding elements and then calculate the average of these differences. Here's a step-by-step explanation for the given arrays:
#
# Calculate the absolute differences:
#
# |68.462395 - 70| = 1.537605
# |72.382774 - 74| = 1.617226
# |76.30314 - 78| = 1.69686
# |80.22351 - 82| = 1.77649
# |84.14388 - 86| = 1.85612
# |88.06425 - 90| = 1.93575
# |91.98461 - 94| = 2.01539
# |95.905 - 98| = 2.095
# |99.82537 - 102| = 2.17463
# |103.74573 - 106| = 2.25427
#
# Calculate the sum of the absolute differences:
#
# 1.537605 + 1.617226 + 1.69686 + 1.77649 + 1.85612 + 1.93575 + 2.01539 + 2.095 + 2.17463 + 2.25427 = 19.95935
#
# Divide the sum of the absolute differences by the total number of elements in the arrays (in this case, 10):
#
# 19.95935 / 10 = 1.995935
#
# So, the mean absolute error (MAE) between the two arrays is approximately 1.995935.

# %%
mae = tf.metrics.mean_absolute_error(y_true = y_test, y_pred=y_pred)
mae
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=1.8959343>

# %%
def mae(y_true, y_pred):
    return tf.metrics.mean_absolute_error(y_true=y_true,
                                          y_pred=tf.squeeze(y_pred))
def mse(y_true, y_pred):
    return tf.metrics.mean_squared_error(y_true=y_true,
                                         y_pred=tf.squeeze(y_pred))
def huber(y_true, y_pred):
    return tf.losses.huber(y_true=y_true,
                           y_pred=tf.squeeze(y_pred)).numpy()

# %%
mse = tf.metrics.mean_squared_error(y_true = y_test, y_pred=y_pred)
mse
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=3.6468787>

# %%
huber = tf.keras.losses.Huber()
huber(y_test, y_pred).numpy()
# Out:
# 1.3959343

# %% [markdown]
# # Running experiments to improve our model

# %%
X_train, y_train
# Out:
# (<tf.Tensor: shape=(40,), dtype=int32, numpy=
#  array([-100,  -96,  -92,  -88,  -84,  -80,  -76,  -72,  -68,  -64,  -60,
#          -56,  -52,  -48,  -44,  -40,  -36,  -32,  -28,  -24,  -20,  -16,
#          -12,   -8,   -4,    0,    4,    8,   12,   16,   20,   24,   28,
#           32,   36,   40,   44,   48,   52,   56], dtype=int32)>,
#  <tf.Tensor: shape=(40,), dtype=int32, numpy=
#  array([-90, -86, -82, -78, -74, -70, -66, -62, -58, -54, -50, -46, -42,
#         -38, -34, -30, -26, -22, -18, -14, -10,  -6,  -2,   2,   6,  10,
#          14,  18,  22,  26,  30,  34,  38,  42,  46,  50,  54,  58,  62,
#          66], dtype=int32)>)

# %%
X_train = tf.cast(X_train, dtype=tf.float32)
y_train = tf.cast(y_train, dtype=tf.float32)

# %%
X_train , y_train
# Out:
# (<tf.Tensor: shape=(40,), dtype=float32, numpy=
#  array([-100.,  -96.,  -92.,  -88.,  -84.,  -80.,  -76.,  -72.,  -68.,
#          -64.,  -60.,  -56.,  -52.,  -48.,  -44.,  -40.,  -36.,  -32.,
#          -28.,  -24.,  -20.,  -16.,  -12.,   -8.,   -4.,    0.,    4.,
#            8.,   12.,   16.,   20.,   24.,   28.,   32.,   36.,   40.,
#           44.,   48.,   52.,   56.], dtype=float32)>,
#  <tf.Tensor: shape=(40,), dtype=float32, numpy=
#  array([-90., -86., -82., -78., -74., -70., -66., -62., -58., -54., -50.,
#         -46., -42., -38., -34., -30., -26., -22., -18., -14., -10.,  -6.,
#          -2.,   2.,   6.,  10.,  14.,  18.,  22.,  26.,  30.,  34.,  38.,
#          42.,  46.,  50.,  54.,  58.,  62.,  66.], dtype=float32)>)

# %%
tf.random.set_seed(42)

# 1. Create a model
model_1 = tf.keras.Sequential([
    tf.keras.layers.Dense(1, input_shape=[1])
])


# 2. Compile the model
model_1.compile(loss=tf.keras.losses.mae,
                optimizer=tf.keras.optimizers.SGD(),
                metrics=['mae'])

# 3. Fit the model
model_1.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 0s 1ms/step - loss: 49.0406 - mae: 49.0406
# Epoch 2/100
# 2/2 [==============================] - 0s 869us/step - loss: 16.8007 - mae: 16.8007
# Epoch 3/100
# 2/2 [==============================] - 0s 725us/step - loss: 15.8945 - mae: 15.8945
# Epoch 4/100
# 2/2 [==============================] - 0s 712us/step - loss: 8.4227 - mae: 8.4227
# Epoch 5/100
# 2/2 [==============================] - 0s 850us/step - loss: 11.0703 - mae: 11.0703
# Epoch 6/100
# 2/2 [==============================] - 0s 880us/step - loss: 10.2262 - mae: 10.2262
# Epoch 7/100
# 2/2 [==============================] - 0s 826us/step - loss: 9.2372 - mae: 9.2372
# Epoch 8/100
# 2/2 [==============================] - 0s 815us/step - loss: 9.1644 - mae: 9.1644
# Epoch 9/100
# 2/2 [==============================] - 0s 780us/step - loss: 11.7884 - mae: 11.7884
# Epoch 10/100
# 2/2 [==============================] - 0s 2ms/step - loss: 13.7143 - mae: 13.7143
# ...

# %%
# Make and plot predictions for model1

y_preds_1 = model_1.predict(X_test)
plot_predictions(predictions = y_preds_1)
# Out:
# 1/1 [==============================] - 0s 20ms/step

# %%
# calculate model_1 evaluation metrics

mae_1 = mae(y_test, y_preds_1)
mse_1 = mse(y_test, y_preds_1)
huber_1 = huber(y_test, y_preds_1)

mae_1, mse_1, huber_1
# Out:
# (<tf.Tensor: shape=(), dtype=float32, numpy=14.990335>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=225.56253>,
#  14.490335)

# %%
model_2 = tf.keras.Sequential([
    tf.keras.layers.Dense(10, input_shape=[1]),
    tf.keras.layers.Dense(1)
])

# 2. Compile the model
model_2.compile(loss=tf.keras.losses.mae,
                optimizer=tf.keras.optimizers.SGD(),
                metrics=['mse'])

# 3. Fit the model
model_2.fit(X_train, y_train, epochs=100)

# Make and plot predictions for model_2
# Out:
# Epoch 1/100
# 2/2 [==============================] - 0s 1ms/step - loss: 32.1372 - mse: 1486.7125
# Epoch 2/100
# 2/2 [==============================] - 0s 1ms/step - loss: 20.7741 - mse: 564.9258
# Epoch 3/100
# 2/2 [==============================] - 0s 830us/step - loss: 26.8929 - mse: 1073.7104
# Epoch 4/100
# 2/2 [==============================] - 0s 729us/step - loss: 27.3505 - mse: 1106.2477
# Epoch 5/100
# 2/2 [==============================] - 0s 1ms/step - loss: 13.3633 - mse: 217.2552
# Epoch 6/100
# 2/2 [==============================] - 0s 1ms/step - loss: 10.7682 - mse: 127.2907
# Epoch 7/100
# 2/2 [==============================] - 0s 956us/step - loss: 11.7249 - mse: 169.1404
# Epoch 8/100
# 2/2 [==============================] - 0s 907us/step - loss: 10.7529 - mse: 126.1122
# Epoch 9/100
# 2/2 [==============================] - 0s 822us/step - loss: 36.3194 - mse: 2011.0671
# Epoch 10/100
# ...

# %%
y_preds_2 = model_2.predict(X_test)
plot_predictions(predictions = y_preds_2)
# Out:
# 1/1 [==============================] - 0s 23ms/step

# %%
mae_2 = mae(y_test, y_preds_2)
mse_2 = mse(y_test, y_preds_2)
huber_2 = huber(y_test, y_preds_2)

mae_2, mse_2, huber_2
# Out:
# (<tf.Tensor: shape=(), dtype=float32, numpy=2.9443443>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=11.403543>,
#  2.465482)

# %%
model_3 = tf.keras.Sequential([
    tf.keras.layers.Dense(10, input_shape=[1]),
    tf.keras.layers.Dense(1)
    
])

# 2. Compile the model
model_3.compile(loss=tf.keras.losses.mae,
                optimizer=tf.keras.optimizers.SGD(),
                metrics=['mae'])

# 3. Fit the model


model_3.fit(X_train, y_train, epochs=500)
# Out:
# Epoch 1/500
# 2/2 [==============================] - 0s 2ms/step - loss: 39.3359 - mae: 39.3359
# Epoch 2/500
# 2/2 [==============================] - 0s 749us/step - loss: 30.4729 - mae: 30.4729
# Epoch 3/500
# 2/2 [==============================] - 0s 780us/step - loss: 35.3119 - mae: 35.3119
# Epoch 4/500
# 2/2 [==============================] - 0s 823us/step - loss: 28.4155 - mae: 28.4155
# Epoch 5/500
# 2/2 [==============================] - 0s 862us/step - loss: 15.4368 - mae: 15.4368
# Epoch 6/500
# 2/2 [==============================] - 0s 787us/step - loss: 12.2545 - mae: 12.2545
# Epoch 7/500
# 2/2 [==============================] - 0s 1ms/step - loss: 11.5480 - mae: 11.5480
# Epoch 8/500
# 2/2 [==============================] - 0s 790us/step - loss: 11.2377 - mae: 11.2377
# Epoch 9/500
# 2/2 [==============================] - 0s 823us/step - loss: 42.1500 - mae: 42.1500
# Epoch 10/500
# 2/2 [==============================] - 0s 2ms/step - loss: 29.3284 - mae: 29.3284
# ...

# %%
y_preds_3 = model_3.predict(X_test)
plot_predictions(predictions = y_preds_3)
# Out:
# 1/1 [==============================] - 0s 35ms/step

# %%
mae_3 = mae(y_test, y_preds_3)
mse_3 = mse(y_test, y_preds_3)
huber_3 = huber(y_test, y_preds_3)
mae_3, mse_3 , huber_3
# Out:
# (<tf.Tensor: shape=(), dtype=float32, numpy=68.11594>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=4724.6924>,
#  67.61594)

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# Compare the result of the experiements of the 3 models

# %%
#Let's compare model result uisng pandas dataframe
import pandas as pd
model_results = [['model_1', mae_1.numpy(), mse_1.numpy(), huber_1],
                ['model_2', mae_2.numpy(), mse_2.numpy(), huber_2],
                ['model_3', mae_3.numpy(), mse_3.numpy(), huber_3]]

all_results = pd.DataFrame(model_results, columns =['model', 'mae', 'mse', 'huber'])
all_results
# Out:
#      model        mae          mse      huber
# 0  model_1  14.990335   225.562531  14.490335
# 1  model_2   2.944344    11.403543   2.465482
# 2  model_3  68.115936  4724.692383  67.615936

# %%
model_2.summary()
# Out:
# Model: "sequential_44"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_77 (Dense)            (None, 10)                20
#
#  dense_78 (Dense)            (None, 1)                 11
#
# ...
# Total params: 31
# Trainable params: 31
# Non-trainable params: 0
# _________________________________________________________________

# %%
# save the model
model_2.save('my_model')
# Out:
# INFO:tensorflow:Assets written to: my_model/assets

# %%
model_2.save('my_model/model_2.h5')

# %%
load_savemodel_format = tf.keras.models.load_model('my_model')
load_savemodel_format.summary()
# Out:
# Model: "sequential_44"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_77 (Dense)            (None, 10)                20
#
#  dense_78 (Dense)            (None, 1)                 11
#
# ...
# Total params: 31
# Trainable params: 31
# Non-trainable params: 0
# _________________________________________________________________

# %%
load_h5_file = tf.keras.models.load_model('my_model/model_2.h5')
load_h5_file.summary()
# Out:
# Model: "sequential_44"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_77 (Dense)            (None, 10)                20
#
#  dense_78 (Dense)            (None, 1)                 11
#
# ...
# Total params: 31
# Trainable params: 31
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_2_preds = model_2.predict(X_test)
load_savemodel_format_preds = load_savemodel_format.predict(X_test)
tf.squeeze(model_2_preds) == tf.squeeze(load_savemodel_format_preds)
# Out:
# ...
# 1/1 [==============================] - 0s 40ms/step
# <tf.Tensor: shape=(10,), dtype=bool, numpy=
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True])>

# %%
load_h5_preds = load_h5_file.predict(X_test)
tf.squeeze(model_2_preds) == tf.squeeze(load_h5_preds)
# Out:
# 1/1 [==============================] - 0s 27ms/step
# <tf.Tensor: shape=(10,), dtype=bool, numpy=
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True])>
